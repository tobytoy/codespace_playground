# %% [markdown]
# ```python
# from pyChatGPT import ChatGPT
#
# session_token = 'abc123'  # `__Secure-next-auth.session-token` cookie from https://chat.openai.com/chat
# api1 = ChatGPT(session_token)  # auth with session token
# api2 = ChatGPT(session_token, proxy='http://proxy.example.com:8080')  # specify proxy
# api3 = ChatGPT(auth_type='google', email='example@gmail.com', password='password') # auth with google login
# api4 = ChatGPT(session_token, verbose=True)  # verbose mode (print debug messages)
#
# resp = api1.send_message('Hello, world!')
# print(resp['message'])
#
# api1.reset_conversation()  # reset the conversation
# api1.close()  # close the session
# ```
#
#
# ##  安裝
#
# ```python
# sudo apt-get update
# sudo apt-get install xvfb
# pip install selenium
# sudo apt-get install chromium-chromedriver
# ```

# %%
from pyChatGPT import ChatGPT

# session_token = 'eyJhbGciOiJkaXIiLCJlbmMiOiJBMjU2R0NNIn0..cQjCDGSDcZlD-tcc.6QQ7KrvMOc0KX20YDD1ULd6sJcoBVqoOTVWoVLGb1HsRAfKEzN5CqZ5ZabmaLq5aDpGOajDtimBS_28GoxI2WfRJexSOa_6JC_W5g3drbLc-4kEnJ3SiTaE18FwONCmS8idUadCIp1U8wgy71H_KFWu7LaSqXxA-3xEk_NMSaO4m5tVvcWgTSA336mC7i8WUsUr62gJT7DUasPUUz3p5CkWJESkZj9ee6e6W9IXnq8H0uuulwdsSSeBD8DRf9ZcWrA8ZJ4fEJhA7b-heBtsSBpdLK8VlWX14SEUD05hREkFFzSPwcBiJgM8p9OG-9BpF4eYGNUqCk3hleg-8aYl9Iq1puIRALH0hKDlXDkBC5Czaz-7D-ZNOx9ioTx_2lv1kHiFF7TGbRSX9nDSByUew8nAbbwn0he02pSm1nZIc4lH7fyvOaY530sWRO43TTQjQb7ZgmuBLKU5ElhE0wZXcgz4_iwEjFeot2UZ-bsmJHDZlGE-Dn1Xd_vEybFYHnEgED5m6gcyAMUHIwTnKMI15IXunxev3PFfBDXVGlWEMZmsr4L3Bw9uK4I8dS1BB8p9-QC8LBBqo1fIJMVhMqjRh3414OG-SkNS-pS8q0OPc1HPQ1aK79ug2nWVgrYIgQsMSs3QTUtiSEMU5_bMKHTMH4gLWLgfVG0oIAVgafs9Drw6Ng0sl6RkfAbGnIubcCiRNKeYgIArmC0oBx0-9TppxxIu6I9nIgZlsVPBAYnTle4RVqQsrDiNxC95xMFerK3Io7DOLSodfMrYXRSCCtaJ1u87H4zYsTaoVx7k3w85mDfZQ4HQfHXuexwuJ5RVUVG83GS9F8jHIU2sEbb_cpnebBsfm4s3iyXHqLVZDsPtbT8tDCkvpckOjt7yL34SHYWOyp4aeSQvac8KOs7sKnodFuIkPqetiRE6Gdo9WG5vj8X7z_VQIqSc8EWGYS8ZRgnLpCGGxCoRkD1-2QMJm9ogmos8iMDcXysxqFft-Y-nTJwHMtVPMdX3yAwC2WqxpHLfPSU8Gv7XLLR8hLaIMScy0vYS52SPA2rkHTaakGlThznC69m4i9FFLqKZiaIPp8l3F-7kc4hHdcYRO-Ux0PUfMnWGzs8pnzsAFJdb-3sSIbct1kAobJMWTJzO0gNQJ220psXHMRGaXYEJGNV94DRy855cdSnTwjI2Dz1apU5K2eJYDtRmk9CfqskTQMcwp8Pd0yNklNGahbnTBCgrPFkAOtiKTr8QzVsredO1QThTPW8LlmEylVTfVsvYkDKtxO9y3e7R6bbA7darvNDWS_49-NdXOSQy9PmAgZ7a5hYAAdVmHvRQCsiTtbhg9_d9JEwuagDSs86ju9akJhqZejRifDPnlUMm6dmbXk5v7K8gwFWwEoq3ZXZRVF5cwgY0wzaZ0kzk46kESaHltaXd5fMBObN-8p8PIs3VmltW-GCefhAauvk0JF2jnHR00wDRLVbEV1uXTgOi42rYbqiJHlFInKLAIx3F2TNmuNCSri78X2gO5Oypxh5OPOMEZPteb1Yc7-iNW9Z5XvRuZo35PJBwefT36M2xHppJzVmg0m38lFHrLy35iXVJ-A1nxOSMn_qgBYO3nD2JiyR0tPC5IstAt1N4rKZEMr-8SfM6ep9JVTyAn2WfkhanPv2tAFrA52xJyeqZYd_HL8akBOaeFPRI2TH32PWhjJKZQ_ifS__CtkqPneSAL8Jonu6oDwCfJKNndo2maaIs4vEaRycjf35pl2DQ2hnHIt1xEr_70LcPVRYB1yqFGRkBtpINStR8kp-5tT3eAUo_g2p16-7bGg-wR8I9AtOQEU24ENYS61VvnhXrsyTbWFzlE5sKfbAnPou-7PbsRbjsjHiSLAlAOFuUdiC-LVL49WP2ygW8kRVHeiAVODdBvO-5e2S5vCmgfAclik5zB2alYkSGoOXzEkFsb7XgZQotnwVUktZ9MNJefth7ukSk6iz2ACd4B1pDbxNHJCK58a9VFdgRhX7-4636qkJA-bQFfGq7w2chkd4yzmgd5c540FWiKu5PBOmt4DmL2TRP0pRpuBkK5oFvUPi7Gj9-R4dB5g9w7hxg-OMBs31T0Qfn1CJLTTmxLyMLSkYFLGwIIoXaUnRj-N621Ad83z64OreH-cMhltTur2SZUwOHERTy7dEBsQ66kj1gEPCN1HSqql4j4-4JJphVbpYPgcX9E72gPDkzIaHHdqWWiUqoOc8DLiWNxszOwIE8nhcROTNstM0fUjSmYRh5r7Pwbc0QGYRRfDrg.sPrA6adzTBw0_lMZO9uMow'



api1 = ChatGPT(auth_type='google', email='email', password='pass')

resp = api1.send_message('Hello, world!')
print(resp['message'])

# %%
from pychatgpt import Chat, Options

options = Options()

# [New] Pass Moderation. https://github.com/rawandahmad698/PyChatGPT/discussions/103
# options.pass_moderation = False

# [New] Enable, Disable logs
options.log = True

# Track conversation
options.track = True 

# Use a proxy
# options.proxies = 'http://localhost:8080'

# Optionally, you can pass a file path to save the conversation
# They're created if they don't exist

# options.chat_log = "chat_log.txt"
# options.id_log = "id_log.txt"

# Create a Chat object
chat = Chat(email="email", password="pass", options=options)
answer = chat.ask("How are you?")
print(answer)

# %%
??Chat
# Out:
# Init signature:
# Chat(
#     email: str,
#     password: str,
#     options: pychatgpt.main.Options = None,
#     conversation_id: str = None,
#     previous_convo_id: str = None,
# )
# Docstring:      <no docstring>
# Source:
# class Chat:
#     def __init__(self,
#                  email: str,
#                  password: str,
#                  options: Options or None = None,
#                  conversation_id: str or None = None,
#                  previous_convo_id: str or None = None):
#         self.email = email
#         self.password = password
#         self.options = options
#
#         self.conversation_id = conversation_id
#         self.previous_convo_id = previous_convo_id
#
#         self.__auth_access_token: str or None = None
#         self.__auth_access_token_expiry: int or None = None
#         self.__chat_history: list or None = None
#
#         self._setup()
#
#     @staticmethod
#     def _create_if_not_exists(file: str):
# ...
